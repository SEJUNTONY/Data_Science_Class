# %% [markdown]
# <a href="https://colab.research.google.com/github/SEJUNTONY/Data_Science_Class/blob/main/%EC%B2%AD%EB%AC%BC%ED%8F%AC21%EA%B8%B0_%EB%8D%B0%EC%82%AC_1117.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 텐서플로우를 통한 자동차 연비 예측

# %%
# 데이터 분석을 위한 pandas, 시각화 위한 seaborn 불러오기

# %%
# 자동차연비 데이터셋 mpg 불러오기

# %% [markdown]
# # 결측치 확인

# %%
# 결측치 합계

# %%
# dropna

# %%
# select_dtypes

# %%
# describe

# %% [markdown]
# # 데이터셋 나누기

# %%
# train_dataset
# test_dataset
# 기출문제로 공부 -> 실전 시험 보는 과정

# %%
# train_dataset, test_dataset에서 label(정답)을 꺼내 label 따로 생성

# %% [markdown]
# # 딥러닝 모델

# %% [markdown]
# ![딥러닝.JPG](data:image/jpeg;base64,...)

# %%
# tensorflow 불러오기

# %% [markdown]
# # 딥러닝 층 구성

# %%
# model = tf.keras.Sequential()
# 64 --> 임의의 숫자를 입력해줘도 된다
# input shape ; 변수의 개수
# model.add(tf.keras.layers.Dense(64, activation="relu", input_shape=[len(train_dataset.keys())]))
# model.add(tf.keras.layers.Dense(64, activation="relu"))
# model.add(tf.keras.layers.Dense(64, activation="relu"))
# model.add(tf.keras.layers.Dense(1))

# %%
# mae : 오차에 대한 절대값의 평균
# mse : 모델의 오차를 어떻게 측정을 할 것인지

# %%
# 만든 모델 확인

# %%
# 딥러닝 모델로 학습하기
# epochs : 몇번을 이용해서 학습을 시킬 것인가
# verbose : log를 어떻게 찍을건지를 의미

# %%
# 딥러닝 모델로 평가
# 평균적으로 절대값이 mae만큼 차이가 난다.
# mse같은 경우, error값을 제곱을 한 값이 mse정도 된다
# mae값을 줄일수록 좋은 모델이라는 것을 확인 가능하다

# %%
# 딥러닝 모델의 예측하기
# flatten() : 1차원 형태로 만들어주기

# %%
# 딥러닝 모델의 예측결과 평가하기
